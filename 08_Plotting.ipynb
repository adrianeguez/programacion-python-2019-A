# %%
import numpy as np
import matplotlib.pyplot as plt

# Configuracion general de los plots revisar documentacion
plt.rcParams['figure.figsize'] = (4,3)
plt.rcParams['figure.dpi'] = 150

# %%
xvals = np.arange(0,10,0.1)

# %%
plt.plot(xvals)

# %%
plt.plot(xvals,np.sin(xvals))

# %%
plt.plot(xvals,
         np.sin(xvals))
plt.plot(xvals,
         np.cos(xvals))
plt.xlabel("x")
plt.ylabel("y")
plt.legend(["SENO","COSENO"])

# %%
nums = np.random.uniform(size=10)
print(nums)
plt.bar(np.arange(10),height=nums)
# Out:
# [0.23560021 0.17900691 0.21929039 0.1530419  0.23245671 0.88767545
#  0.74976842 0.16578312 0.20583462 0.28595412]
# <BarContainer object of 10 artists>
